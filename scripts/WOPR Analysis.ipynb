# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv('C:/Users/Ryan/Documents/air_yards_model/data/airyards_data.csv')

# %%
fig = px.scatter(x=df['season_avg_wopr'], y=df['season_avg_fantasy_points_ppr'], trendline="ols")
fig.show()

# %%
results = px.get_trendline_results(fig)
results = results.iloc[0]["px_fit_results"].summary()
print(results)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                 8.320e+04
# Date:                Thu, 06 Oct 2022   Prob (F-statistic):               0.00
# Time:                        15:32:17   Log-Likelihood:                -88774.
# No. Observations:               35311   AIC:                         1.776e+05
# Df Residuals:                   35309   BIC:                         1.776e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5826      0.033     17.800      0.000       0.518       0.647
# ...
